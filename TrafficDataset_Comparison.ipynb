# %%
import pickle
rf_performance_metric = pickle.load(open('PerformanceMetric/rf_traffic.sav', 'rb'))
rf_performance_metric
# Out:
# (0.9997469738067285,
#  0.9587278217820012,
#  0.9280272719707483,
#  0.9421541601979777)

# %%
cb_performance_metric = pickle.load(open('PerformanceMetric/catboost_traffic.sav', 'rb'))
cb_performance_metric
# Out:
# (0.9998178211408445, 0.9630026828825754, 0.973230991657176, 0.9676912109088469)
